# %% [markdown]
# <a
# href="https://colab.research.google.com/github/wingated/cs474_labs_f2019/blob/master/DL_Lab7.ipynb"
#   target="_parent">
#   <img
#     src="https://colab.research.google.com/assets/colab-badge.svg"
#     alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Lab 7: The Transformer
# ### Description:
# For this lab, you will fill in the attention mechanism for the Transformer architecture.
#
# There are three parts of this lab:
# 1. Implement scaled dot-product attention
# 2. Implement a multi-headded attention mechanism
# 3. Translate general conference!
#
#
# ### Grading standards
#
# Your code will be graded on the following:
#
# - 45% Implementation of scaled dot-product attention
# - 45% Implementation of multi-headed attention mechanism
# - 10% Reasonable translation of general conference
#
# Note: This lab was adapted from "The Annotated Transformer", a publically available PyTorch implementation of the Transformer. This lab only requires about 20 lines of code, but we want you to think hard about the dimensions on which different operations apply, and debug accordingly. This will be trivial if you use the implementation for reference, but will be a worthwhile learning exercise if you don't. So we ask you not to reference that particular implementation, though you are free to reference other implementations (see references below).
#
#
# ### Tips:
# A couple of tips for this lab:
# 0. The provided code instantiates the `MultiHeadedAttention` class for you. For a start, try printing the dimensions of `key`, `query`, and `values` in the `forward()` function the `MultiHeadedAttention` class.
# 1. The key to this lab is section 3.2 of "Attention is All you Need". This section will tell you pretty much all you need to know about dimensions. https://arxiv.org/pdf/1706.03762.pdf
# 2. The queries, keys, and values come in the form N x L x d_model, where N is the batch size, L is the sentence length, and d_model is the dimension of the embedding. Both the batch size and the sentence length vary across training instances. Think about what each dimension means to find out which dimensions you'll want to perform each operation on.
# 3. There are 3 pytorch implementations of matrix multiplication: torch.bmm, torch.mm, and torch.matmul. You'll want to figure out which one to use for this lab.
# 4. There are 3 pytorch implementations of transpose: torch.t, torch.transpose, and torch.permute. You'll want to figure out which one of those to use as well.
# 5. This implementation provides a `clones()` function that you may find useful in the MultiHeadedAttention class
#
# ### Example Output
# An example of my final samples are shown below, after 3 epochs through the data. You should expect each epoch to take ~10 minutes, and should see reasonable results after the first epoch.
#
# Spanish:	Muchos miembros de la Iglesia tuvieron fe en las profecías de Brigham Young , mientras que otros se mostraron escépticos y partieron hacia lo que ellos creían que sería una vida mejor .
#
# Translation:	Many members of the Church had faith in Brigham Young , while others who showed and other mocking to what they would be better than they would be better better than they would better .
#
# Target:		Many Church members had faith in Brigham Young ’s prophecies , while others remained <unk> and left for what they assumed would be a better life .

# %% [markdown]
# ### Based on "Attention is All You Need" (https://arxiv.org/abs/1706.03762) and "The Annotated Transformer" (https://nlp.seas.harvard.edu/2018/04/03/attention.html)
# ### Also useful:
# http://jalammar.github.io/illustrated-transformer/
#
# https://github.com/jadore801120/attention-is-all-you-need-pytorch/blob/master/transformer/

# %% [markdown]
# ## Setup

# %%
# !pip install torch==1.9.0

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import math, copy, time
from torch.autograd import Variable
import matplotlib.pyplot as plt
import seaborn
seaborn.set_context(context="talk")
# %matplotlib inline

# Download english and spanish vocab and general conference texts
# !pip install torchtext==0.10.0
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download es_core_news_sm
# !wget  -O ./spanish "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt"
# !wget -O ./english "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.9.0
#   Downloading torch-1.9.0-cp38-cp38-manylinux1_x86_64.whl (831.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.4/831.4 MB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.9.0) (4.5.0)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1+cu116
#     Uninstalling torch-1.13.1+cu116:
#       Successfully uninstalled torch-1.13.1+cu116
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.14.1+cu116 requires torch==1.13.1, but you have torch 1.9.0 which is incompatible.
# torchtext 0.14.1 requires torch==1.13.1, but you have torch 1.9.0 which is incompatible.
# torchaudio 0.13.1+cu116 requires torch==1.13.1, but you have torch 1.9.0 which is incompatible.
# Successfully installed torch-1.9.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchtext==0.10.0
#   Downloading torchtext-0.10.0-cp38-cp38-manylinux1_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 69.8 MB/s eta 0:00:00
# Requirement already satisfied: torch==1.9.0 in /usr/local/lib/python3.8/dist-packages (from torchtext==0.10.0) (1.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchtext==0.10.0) (2.25.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from torchtext==0.10.0) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchtext==0.10.0) (1.22.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.9.0->torchtext==0.10.0) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.10.0) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.10.0) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.10.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.10.0) (1.26.14)
# Installing collected packages: torchtext
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.14.1
#     Uninstalling torchtext-0.14.1:
#       Successfully uninstalled torchtext-0.14.1
# Successfully installed torchtext-0.10.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (3.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.25.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (8.1.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.22.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (23.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.10.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy) (2.1.2)
# 2023-03-04 19:00:00.663429: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-04 19:00:03.937948: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-04 19:00:03.938348: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-04 19:00:03.938372: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 97.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from en-core-web-sm==3.4.1) (3.4.4)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.22.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.9)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.25.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.5)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (6.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (57.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (23.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.12)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.10)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# 2023-03-04 19:00:18.172530: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-04 19:00:19.042115: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-04 19:00:19.042236: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-04 19:00:19.042255: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting es-core-news-sm==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.4.0/es_core_news_sm-3.4.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from es-core-news-sm==3.4.0) (3.4.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (57.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.10.5)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (23.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.4.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (6.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.7.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.25.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (8.1.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.0.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.0.4)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.22.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (4.64.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.0.12)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.10.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.0.9)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.10.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (4.0.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.1.2)
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.4.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# --2023-03-04 19:00:32--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8617078 (8.2M) [text/plain]
# Saving to: ‘./spanish’
#
# ./spanish           100%[===================>]   8.22M  --.-KB/s    in 0.02s
#
# 2023-03-04 19:00:33 (402 MB/s) - ‘./spanish’ saved [8617078/8617078]
#
# --2023-03-04 19:00:33--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7755011 (7.4M) [text/plain]
# Saving to: ‘./english’
#
# ./english           100%[===================>]   7.40M  --.-KB/s    in 0.02s
#
# 2023-03-04 19:00:34 (391 MB/s) - ‘./english’ saved [7755011/7755011]

# %% [markdown]
# # Model

# %% [markdown]
# ## Model Helpers

# %%
class PositionwiseFeedForward(nn.Module):
    "Simple linear layers with dropout and relu"
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))

class Embeddings(nn.Module):
    "Create word embeddings"
    def __init__(self, d_model, vocab):
        super(Embeddings, self).__init__()
        self.lut = nn.Embedding(vocab, d_model)
        self.d_model = d_model

    def forward(self, x):
        return self.lut(x) * math.sqrt(self.d_model)

class Generator(nn.Module):
    "Define standard linear + softmax generation step."
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)

class LayerNorm(nn.Module):
    "Construct a layernorm module "
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2

class SublayerConnection(nn.Module):
    """
    A residual connection followed by a layer norm.
    Note for code simplicity the norm is first as opposed to last.
    """
    def __init__(self, size, dropout):
        super(SublayerConnection, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        "Apply residual connection to any sublayer with the same size."
        return x + self.dropout(sublayer(self.norm(x)))

def clones(module, N):
    "Produce N identical layers."
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

# %% [markdown]
# ## Encoder
#
# The encoder is composed of a stack of $N=6$ identical layers.

# %%
class Encoder(nn.Module):
    "Core encoder is a stack of N layers"
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)

    def forward(self, x, mask):
        "Pass the input (and mask) through each layer in turn."
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)



class EncoderLayer(nn.Module):
    "Encoder is made up of self-attn and feed forward "
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 2)
        self.size = size

    def forward(self, x, mask):
        "Follow Figure 1 (left) for connections."
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, mask))
        return self.sublayer[1](x, self.feed_forward)

# %% [markdown]
# ## Decoder
#
# The decoder is also composed of a stack of $N=6$ identical layers.

# %%
class Decoder(nn.Module):
    "Generic N layer decoder with masking."
    def __init__(self, layer, N):
        super(Decoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)

    def forward(self, x, memory, src_mask, tgt_mask):
        for layer in self.layers:
            x = layer(x, memory, src_mask, tgt_mask)
        return self.norm(x)

class DecoderLayer(nn.Module):
    "Decoder is made of self-attn, src-attn, and feed forward (defined below)"
    def __init__(self, size, self_attn, src_attn, feed_forward, dropout):
        super(DecoderLayer, self).__init__()
        self.size = size
        self.self_attn = self_attn
        self.src_attn = src_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 3)

    def forward(self, x, memory, src_mask, tgt_mask):
        "Follow Figure 1 (right) for connections."
        m = memory
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, tgt_mask))
        x = self.sublayer[1](x, lambda x: self.src_attn(x, m, m, src_mask))
        return self.sublayer[2](x, self.feed_forward)

def subsequent_mask(size):
    "Mask out subsequent positions."
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

# %% [markdown]
# ## Implement Attention
#
#
# https://arxiv.org/pdf/1706.03762.pdf

# %%
import pdb

# %%
'''
torch.Size([58, 13, 256])
torch.Size([58, 1, 13])
torch.Size([58, 13, 256])
'''
# Out:
# '\ntorch.Size([58, 13, 256])\ntorch.Size([58, 1, 13])\ntorch.Size([58, 13, 256])\n'

# %%
def attention(query, key, value, mask):
    # Compute 'Scaled Dot Product Attention'

    # scores = QK^T/scale
    query = query / (query.size()[2] **(1 / 4))
    key = key / (key.size()[2] **(1 / 4))

    scores = torch.bmm(query, key.transpose(1, 2))

    # Apply the mask
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)

    # output = softmax(scores)(V)

    output = torch.bmm(F.softmax(scores, dim=2), value)

    return output

# %%
class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model, dropout=0.1):
        super(MultiHeadedAttention, self).__init__()
        # Implement Multi-head attention mechanism
        self.h = h

        # Make an attention head (linear layers for q, k, and v)
        toquery = nn.Linear(d_model, d_model // h, bias=False)
        tokey = nn.Linear(d_model, d_model // h, bias=False)
        tovalue = nn.Linear(d_model, d_model // h, bias=False)

        # # Make h copies of the attention head (Hint: See the `clone()` helper function)
        self.toqueries = clones(toquery, h)
        self.tokeys = clones(tokey, h)
        self.tovalues = clones(tovalue, h)

        # etc.
        self.unifyheads = nn.Linear(d_model, d_model)

    def forward(self, query, key, value, mask):
        # For each attention head
            # Pass the query, key, value through their respective layers
            # Compute scaled dot-product attention on the output
        # etc.
        b, s, d = query.size()

        outputs = []

        for toquery, tokey, tovalue in zip(self.toqueries, self.tokeys, self.tovalues):
          q = toquery(query)
          k = tokey(key)
          v = tovalue(value)

          outputs.append(attention(q, k, v, mask))

        out = torch.cat(outputs, 2)

        return self.unifyheads(out)

# %% [markdown]
# ## Positional Encoding
# Since our model contains no recurrence and no convolution, in order for the model to make use of the order of the sequence, we must inject some information about the relative or absolute position of the tokens in the sequence.  To this end, we add "positional encodings" to the input embeddings at the bottoms of the encoder and decoder stacks.  The positional encodings have the same dimension $d_{\text{model}}$ as the embeddings, so that the two can be summed.   There are many choices of positional encodings, learned and fixed [(cite)](https://arxiv.org/pdf/1705.03122.pdf).
#
# In this work, we use sine and cosine functions of different frequencies:
# $$PE_{(pos,2i)} = sin(pos / 10000^{2i/d_{\text{model}}})$$
#
# $$PE_{(pos,2i+1)} = cos(pos / 10000^{2i/d_{\text{model}}})$$
# where $pos$ is the position and $i$ is the dimension.  That is, each dimension of the positional encoding corresponds to a sinusoid.  The wavelengths form a geometric progression from $2\pi$ to $10000 \cdot 2\pi$.  We chose this function because we hypothesized it would allow the model to easily learn to attend by relative positions, since for any fixed offset $k$, $PE_{pos+k}$ can be represented as a linear function of $PE_{pos}$.
#
# In addition, we apply dropout to the sums of the embeddings and the positional encodings in both the encoder and decoder stacks.  For the base model, we use a rate of $P_{drop}=0.1$.

# %%
class PositionalEncoding(nn.Module):
    "Implement the PE function."
    def __init__(self, d_model, dropout, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        # Compute the positional encodings once in log space.
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len).unsqueeze(1).float()
        div_term = 1 / (10000 ** (torch.arange(0., d_model, 2) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + Variable(self.pe[:, :x.size(1)],
                         requires_grad=False)
        return self.dropout(x)

# %%
plt.figure(figsize=(15, 5))
pe = PositionalEncoding(20, 0)
y = pe.forward(Variable(torch.zeros(1, 100, 20)))
plt.plot(np.arange(100), y[0, :, 4:8].data.numpy())
plt.legend(["dim %d"%p for p in [4,5,6,7]])
None

# %% [markdown]
# ## Full Model

# %%
class TransformerModel(nn.Module):
    """
    Full transformer model
    """
    def __init__(self, src_vocab, tgt_vocab, N=6, d_model=256, d_ff=1024, h=8, dropout=0.1):
        super(TransformerModel, self).__init__()

        attn = MultiHeadedAttention(h, d_model)
        ff = PositionwiseFeedForward(d_model, d_ff, dropout)
        position = PositionalEncoding(d_model, dropout)
        c = copy.deepcopy

        self.encoder = Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N)
        self.decoder = Decoder(DecoderLayer(d_model, c(attn), c(attn),
                             c(ff), dropout), N)
        self.src_embed = nn.Sequential(Embeddings(d_model, src_vocab), c(position))
        self.tgt_embed = nn.Sequential(Embeddings(d_model, tgt_vocab), c(position))
        self.generator = Generator(d_model, tgt_vocab)
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)

    def forward(self, src, tgt, src_mask, tgt_mask):
        "Take in and process masked src and target sequences."
        return self.decode(self.encode(src, src_mask), src_mask,
                            tgt, tgt_mask)

    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)

    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)

# %% [markdown]
# # Training

# %% [markdown]
# ## Batches and Masking

# %%
class Batch:
    "Object for holding a batch of data with mask during training."
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :-1]
            self.trg_y = trg[:, 1:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()

    @staticmethod
    def make_std_mask(tgt, pad):
        "Create a mask to hide padding and future words."
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask


global max_src_in_batch, max_tgt_in_batch
def batch_size_fn(new, count, sofar):
    "Keep augmenting batch and calculate total number of tokens + padding."
    global max_src_in_batch, max_tgt_in_batch
    if count == 1:
        max_src_in_batch = 0
        max_tgt_in_batch = 0
    max_src_in_batch = max(max_src_in_batch,  len(new.src))
    max_tgt_in_batch = max(max_tgt_in_batch,  len(new.trg) + 2)
    src_elements = count * max_src_in_batch
    tgt_elements = count * max_tgt_in_batch
    return max(src_elements, tgt_elements)

# %% [markdown]
# ## Label Smoothing
#
# During training, we employed label smoothing of value $\epsilon_{ls}=0.1$ [(cite)](https://arxiv.org/abs/1512.00567).  This hurts perplexity, as the model learns to be more unsure, but improves accuracy and BLEU score.

# %%
class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(reduction='sum')
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None

    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist[:, self.padding_idx] = 0
        mask = torch.nonzero(target.data == self.padding_idx)
        if mask.dim() > 0:
            true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))

# %% [markdown]
# ## Data Loading

# %%
from torchtext.legacy import data, datasets
import torchtext
import spacy

# Load spacy tokenizers.
spacy_es = spacy.load('es_core_news_sm')
spacy_en = spacy.load('en_core_web_sm')

def tokenize_es(text):
    return [tok.text for tok in spacy_es.tokenizer(text)]

def tokenize_en(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

BOS_WORD = '<s>'
EOS_WORD = '</s>'
BLANK_WORD = "<blank>"
SRC = data.Field(tokenize=tokenize_es, pad_token=BLANK_WORD)
TGT = data.Field(tokenize=tokenize_en, init_token = BOS_WORD,
                 eos_token = EOS_WORD, pad_token=BLANK_WORD)

print("Loading Dataset")
with open('./spanish', 'r', encoding='utf-8') as spanish_text:
  spanish_lines = list(spanish_text)
with open('./english', 'r', encoding='utf-8') as english_text:
  english_lines = list(english_text)

fields = (["src", SRC], ["trg", TGT])
examples = [data.Example.fromlist((spanish_lines[i], english_lines[i]), fields ) for i in range(len(english_lines))]

MAX_LEN = 200
train, val = data.Dataset(examples, fields=fields, filter_pred=lambda x: len(vars(x)['src']) <= MAX_LEN and
        len(vars(x)['trg']) <= MAX_LEN).split()

MIN_FREQ = 1
SRC.build_vocab(train.src, min_freq=MIN_FREQ)
TGT.build_vocab(train.trg, min_freq=MIN_FREQ)
# Out:
# Loading Dataset

# %% [markdown]
# ## Training Code

# %%
class LossFunction:
    "A simple loss compute and train function."
    def __init__(self, generator, criterion, opt=None):
        self.generator = generator
        self.criterion = criterion
        self.opt = opt

    def __call__(self, x, y, norm):
        x = self.generator(x)
        loss = self.criterion(x.contiguous().view(-1, x.size(-1)),
                              y.contiguous().view(-1)) / norm
        loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.zero_grad()
        return loss.data * norm

class DataIterator(data.Iterator):
    def create_batches(self):
        if self.train:
            def pool(d, random_shuffler):
                for p in data.batch(d, self.batch_size * 100):
                    p_batch = data.batch(
                        sorted(p, key=self.sort_key),
                        self.batch_size, self.batch_size_fn)
                    for b in random_shuffler(list(p_batch)):
                        yield b
            self.batches = pool(self.data(), self.random_shuffler)

        else:
            self.batches = []
            for b in data.batch(self.data(), self.batch_size,
                                          self.batch_size_fn):
                self.batches.append(sorted(b, key=self.sort_key))

def rebatch(pad_idx, batch):
    "Fix order in torchtext to match ours"
    src, trg = batch.src.transpose(0, 1).cuda(), batch.trg.transpose(0, 1).cuda()
    return Batch(src, trg, pad_idx)


def run_epoch(data_iter, model, loss_compute):
    "Standard Training and Logging Function"
    start = time.time()
    total_tokens = 0
    total_loss = 0
    tokens = 0
    for i, batch in enumerate(data_iter):
        out = model.forward(batch.src, batch.trg,
                            batch.src_mask, batch.trg_mask)
        loss = loss_compute(out, batch.trg_y, batch.ntokens)
        total_loss += loss
        total_tokens += batch.ntokens
        tokens += batch.ntokens
        if i % 50 == 1:
            elapsed = time.time() - start
            print("Epoch Step: %d Loss: %f Tokens per Sec: %f" %
                    (i, loss / batch.ntokens, tokens / elapsed))
            start = time.time()
            tokens = 0
    return total_loss / total_tokens

# %% [markdown]
# ## Train

# %%
import gc
gc.collect()

pad_idx = TGT.vocab.stoi["<blank>"]
model = TransformerModel(len(SRC.vocab), len(TGT.vocab), N=2).cuda()
n_epochs = 10
device = torch.device('cuda')

def scope():
    criterion = LabelSmoothing(size=len(TGT.vocab), padding_idx=pad_idx, smoothing=0.1)
    criterion.cuda()
    BATCH_SIZE = 1000
    train_iter = DataIterator(train, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=True)
    valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=False)

    model_opt = torch.optim.Adam(model.parameters(), lr=5e-4)
    for epoch in range(n_epochs):
        model.train()
        l = run_epoch((rebatch(pad_idx, b) for b in train_iter),
                  model,
                  LossFunction(model.generator, criterion, model_opt))
        train_losses.append(l)
        model.eval()
scope()
# Out:
# Epoch Step: 1 Loss: 8.664495 Tokens per Sec: 3970.884521
# Epoch Step: 51 Loss: 5.975063 Tokens per Sec: 11386.799805
# Epoch Step: 101 Loss: 5.686491 Tokens per Sec: 12470.380859
# Epoch Step: 151 Loss: 5.389788 Tokens per Sec: 10622.714844
# Epoch Step: 201 Loss: 4.926093 Tokens per Sec: 11978.412109
# Epoch Step: 251 Loss: 5.175886 Tokens per Sec: 12943.762695
# Epoch Step: 301 Loss: 5.342476 Tokens per Sec: 13010.755859
# Epoch Step: 351 Loss: 4.650688 Tokens per Sec: 10189.206055
# Epoch Step: 401 Loss: 4.598115 Tokens per Sec: 13033.503906
# Epoch Step: 451 Loss: 4.843168 Tokens per Sec: 13044.086914
# Epoch Step: 501 Loss: 4.543509 Tokens per Sec: 11822.095703
# Epoch Step: 551 Loss: 4.399698 Tokens per Sec: 11399.752930
# Epoch Step: 601 Loss: 4.578977 Tokens per Sec: 10881.042969
# Epoch Step: 651 Loss: 4.824237 Tokens per Sec: 12905.021484
# Epoch Step: 701 Loss: 4.177289 Tokens per Sec: 10340.381836
# Epoch Step: 751 Loss: 4.244920 Tokens per Sec: 12831.346680
# Epoch Step: 801 Loss: 4.293138 Tokens per Sec: 12348.044922
# Epoch Step: 851 Loss: 4.027108 Tokens per Sec: 10891.704102
# Epoch Step: 901 Loss: 4.044010 Tokens per Sec: 11935.340820
# Epoch Step: 951 Loss: 3.859721 Tokens per Sec: 12933.899414
# Epoch Step: 1001 Loss: 3.619293 Tokens per Sec: 13097.955078
# Epoch Step: 1051 Loss: 3.480818 Tokens per Sec: 10272.514648
# Epoch Step: 1101 Loss: 3.420901 Tokens per Sec: 12460.088867
# Epoch Step: 1151 Loss: 4.066673 Tokens per Sec: 13174.452148
# Epoch Step: 1201 Loss: 3.567122 Tokens per Sec: 10500.708008
# Epoch Step: 1251 Loss: 3.509597 Tokens per Sec: 11715.605469
# Epoch Step: 1301 Loss: 3.268090 Tokens per Sec: 12842.463867
# Epoch Step: 751 Loss: 1.035188 Tokens per Sec: 12600.334961
# Epoch Step: 801 Loss: 0.395750 Tokens per Sec: 10819.975586
# Epoch Step: 851 Loss: 0.812532 Tokens per Sec: 12486.372070
# Epoch Step: 901 Loss: 0.867672 Tokens per Sec: 12932.850586
# Epoch Step: 951 Loss: 0.816093 Tokens per Sec: 10273.565430
# Epoch Step: 1001 Loss: 0.937540 Tokens per Sec: 12477.018555
# Epoch Step: 1051 Loss: 0.447368 Tokens per Sec: 12986.777344
# Epoch Step: 1101 Loss: 0.851846 Tokens per Sec: 12803.188477
# Epoch Step: 1151 Loss: 1.086483 Tokens per Sec: 10410.216797
# Epoch Step: 1201 Loss: 0.963983 Tokens per Sec: 12515.251953
# Epoch Step: 1251 Loss: 0.880426 Tokens per Sec: 13022.070312
# Epoch Step: 1301 Loss: 1.198530 Tokens per Sec: 10646.314453
# Epoch Step: 1 Loss: 0.780139 Tokens per Sec: 4030.729004
# Epoch Step: 51 Loss: 0.628951 Tokens per Sec: 12713.880859
# Epoch Step: 101 Loss: 0.896071 Tokens per Sec: 12941.157227
# Epoch Step: 151 Loss: 0.877694 Tokens per Sec: 11839.998047
# Epoch Step: 201 Loss: 0.949126 Tokens per Sec: 10670.065430
# Epoch Step: 251 Loss: 0.627836 Tokens per Sec: 12779.006836
# Epoch Step: 301 Loss: 0.938236 Tokens per Sec: 13220.455078
# Epoch Step: 351 Loss: 0.679497 Tokens per Sec: 9943.565430
# Epoch Step: 401 Loss: 0.790632 Tokens per Sec: 12493.876953
# Epoch Step: 451 Loss: 0.928744 Tokens per Sec: 12731.583984
# Epoch Step: 501 Loss: 0.850670 Tokens per Sec: 11987.415039
# Epoch Step: 551 Loss: 0.830641 Tokens per Sec: 10845.091797
# Epoch Step: 601 Loss: 0.920064 Tokens per Sec: 12873.987305
# Epoch Step: 651 Loss: 0.803044 Tokens per Sec: 13256.985352
# Epoch Step: 701 Loss: 0.835292 Tokens per Sec: 10991.005859
# Epoch Step: 751 Loss: 0.804537 Tokens per Sec: 12618.684570
# Epoch Step: 801 Loss: 0.661715 Tokens per Sec: 13132.808594
# Epoch Step: 851 Loss: 0.592971 Tokens per Sec: 13032.936523
# Epoch Step: 901 Loss: 0.813644 Tokens per Sec: 10243.840820
# Epoch Step: 951 Loss: 0.905491 Tokens per Sec: 13431.571289
# Epoch Step: 1001 Loss: 0.956667 Tokens per Sec: 13007.663086
# Epoch Step: 1051 Loss: 0.530245 Tokens per Sec: 10997.542969
# Epoch Step: 1101 Loss: 0.912782 Tokens per Sec: 11598.838867
# Epoch Step: 1151 Loss: 0.962072 Tokens per Sec: 13238.778320
# Epoch Step: 1201 Loss: 0.856297 Tokens per Sec: 13097.337891
# Epoch Step: 1251 Loss: 0.967544 Tokens per Sec: 9807.710938
# Epoch Step: 1301 Loss: 0.853202 Tokens per Sec: 12951.689453

# %% [markdown]
# ## Translate

# %%
def greedy_decode(model, src, src_mask, max_len, start_symbol):
    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type_as(src.data)
    for i in range(max_len-1):
        out = model.decode(memory, src_mask,
                           Variable(ys),
                           Variable(subsequent_mask(ys.size(1))
                                    .type_as(src.data)))
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim = 1)
        next_word = next_word.data[0]
        ys = torch.cat([ys,
                        torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=1)
    return ys

BATCH_SIZE = 1000
n_train_iters = len(train) / BATCH_SIZE
valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                        repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                        batch_size_fn=batch_size_fn, train=False)

for i, batch in enumerate(valid_iter):
    src = batch.src.transpose(0, 1)[:1].cuda()
    src_mask = (src != SRC.vocab.stoi["<blank>"]).unsqueeze(-2).cuda()
    out = greedy_decode(model, src, src_mask,
                        max_len=60, start_symbol=TGT.vocab.stoi["<s>"])
    print("Spanish:", end="\t")
    for i in range(0, src.size(1)):
        sym = SRC.vocab.itos[src[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Translation:", end="\t")
    for i in range(1, out.size(1)):
        sym = TGT.vocab.itos[out[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Target:\t", end="\t")
    for i in range(1, batch.trg.size(0)):
        sym = TGT.vocab.itos[batch.trg.data[i, 0]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print()

    if i > 1000 and i<1100:
        break
# Out:
# Spanish:	De los Setenta
# Translation:	Of the Seventy
# Target:		Of the Seventy
#
# Spanish:	Asistir al templo
# Translation:	Going to the temple
# Target:		Attending the temple
#
# Spanish:	El amor es perdonar
# Translation:	Love Is Mercy
# Target:		Love Is Forgiveness
#
# Spanish:	El Salvador dijo :
# Translation:	The Savior said :
# Target:		The Savior said :
#
# Spanish:	Élder D. Todd Christofferson
# Translation:	Elder D. Todd Christofferson
# Target:		Elder D. Todd Christofferson
#
# Spanish:	Lo sé ’ .
# Translation:	I know . ’
# Target:		I know it . ’
#
# Spanish:	Cantemos todos a Jesús
# Translation:	We ’ll sing all hail to Jesus ’ name .
# Target:		We ’ll sing all hail to Jesus ’ name ,
#
# Spanish:	¡ Es verdad ! .
# Translation:	It is true !
# Target:		It is true !
#
# Spanish:	¿ Cuán <unk> estamos ?
# Translation:	How do we ’re Taught
# Target:		How repentant are we ?
#
# Spanish:	Doctrina y Convenios 1:38 .
# Translation:	Doctrine and Covenants 1:38 .
# Target:		Doctrine and Covenants 1:38 .
#
# Spanish:	Doctrina and Convenios 1:23 .
# Translation:	Doctrine and Covenants 1:23 .
# Target:		Doctrine and Covenants 1:23 .
#
# Spanish:	tu pueblo a <unk> .
# Translation:	Thy Day
# Target:		To set thy people free .
#
# Spanish:	Pero Dios no desistió .
# Translation:	But God did not give up on Moses .
# Target:		But God did not give up on Moses .
#
# Spanish:	Sesión del domingo por la mañana
# Translation:	Sunday Morning Session
# Target:		Sunday Morning Session
#
# Spanish:	por la falta de visión ,
# Translation:	By the lack of vision
# Target:		For the <unk> of sight
#
# Spanish:	Después , seleccione un idioma .
# Translation:	Then select a language .
# Target:		Then select a language .
#
# Spanish:	Mateo 7:21 ; cursiva agregada .
# Translation:	Matthew 7:21 ; emphasis added .
# Target:		Matthew 7:21 ; emphasis added .
#
# Spanish:	Véase Manual 2 , 1.3.3 .
# Translation:	See Handbook 2 , 2.1.1 .
# Target:		See Handbook 2 , 1.3.3 .
#
# Spanish:	En palabras del rey Benjamín :
# Translation:	In the words of King Benjamin :
# Target:		In the words of King Benjamin :
#
# Spanish:	Introducción del Libro de Mormón .
# Translation:	It is proposed from the Book of Mormon .
# Target:		<unk> to the Book of Mormon .
#
# Spanish:	Un ruego a favor de los jóvenes
# Translation:	A Plea to My Youth
# Target:		Plea for the Youth
#
# Spanish:	La revelación terminó con la Biblia .
# Translation:	Revelation was completed with the Bible .
# Target:		Revelation ended with the Bible .
#
# Spanish:	Véase Hechos <unk> ; Romanos <unk> .
# Translation:	See Acts 9:1–9 ; 26:13–18 .
# Target:		See Acts <unk> ; Romans <unk> .
#
# Spanish:	Doy testimonio de Su realidad viviente .
# Translation:	I bear witness of His living reality .
# Target:		I witness of His living reality .
#
# Spanish:	Presidente del Cuórum de los Doce Apóstoles
# Translation:	President of the Quorum of the Twelve Apostles
# Target:		President of the Quorum of the Twelve Apostles
#
# Spanish:	La amamos , observamos y esperamos .
# Translation:	We love you , and we hope .
# Target:		We loved , we watched , and we waited .
#
# Spanish:	Dicha persona podría ser incluso usted mismo .
# Translation:	This person could be even you .
# Target:		That person may even be you .
#
# Spanish:	Las Escrituras están llenas de esos ejemplos .
# Translation:	The scriptures are filled with these examples .
# Target:		The scriptures are full of such examples .
#
# Spanish:	Véase Mosíah <unk> ; 2 Corintios 5:17 .
# Translation:	See Mosiah 3:5–18 ; 2 Corinthians 5:17 .
# Target:		See Mosiah <unk> ; 2 Corinthians 5:17 .
#
# Spanish:	El segundo es proponer una mejor manera .
# Translation:	The second is a better way .
# Target:		The second is to suggest a better way .
#
# Spanish:	Ésta es la verdadera Iglesia de Jesucristo .
# Translation:	This is the true Church of Jesus Christ .
# Target:		This is the true Church of Jesus Christ .
#
# Spanish:	El joven y la jovencita decidieron bautizarse .
# Translation:	The young woman and the young woman decided to be baptized .
# Target:		The boy and the girl chose to be baptized .
#
# Spanish:	Las decisiones que tomamos determinan nuestro destino .
# Translation:	The choices we make determine our destiny .
# Target:		May we ever choose the harder right instead of the easier wrong .
#
# Spanish:	Segunda Consejera de la Presidencia General de la Primaria
# Translation:	Second Counselor in the Primary General Presidency
# Target:		Second Counselor in the Primary General Presidency
#
# Spanish:	Él respondió : “ Llévatelo de todos modos .
# Translation:	He replied , “ It ’s all right .
# Target:		He answered , “ Take it anyway .
#
# Spanish:	Las enseñanzas de Aarón inspiraron profundamente al rey .
# Translation:	The teachings of Aaron deeply inspired the king .
# Target:		The teachings of Aaron inspired the king deeply .
#
# Spanish:	<unk> un vistazo a los cambios en conference.lds.org .
# Translation:	He yearned to see changes in English .
# Target:		Take a look at the changes at conference.lds.org .
#
# Spanish:	“ ¡ Oh Rey de reyes ven ! ”
# Translation:	“ Come , O thou King of Kings ! ”
# Target:		“ Come , O thou King of Kings ! ”
#
# Spanish:	De esta vida al sepulcro pasará el hombre .
# Translation:	In this life the grave the whole part of this life will pass .
# Target:		Man passeth from life to his rest in the grave .
#
# Spanish:	de modo que volvieron inmediatamente a su obispo y
# Translation:	So immediately , he went to his bishop and his bishop and his bishop .
# Target:		So they turned around quickly to go again to their bishop .
#
# Spanish:	Los que estén en contra , si los hay .
# Translation:	Those opposed , if any .
# Target:		Those opposed , if any .
#
# Spanish:	Uno debe estar dispuesto a ofender , a arriesgarse .
# Translation:	A person is willing to offend .
# Target:		That ’s where the faith comes in .
#
# Spanish:	El arrepentimiento es una de esas decisiones correctas vitales .
# Translation:	Repentance is a part of these correct choices .
# Target:		Repentance is one of those critical correct choices .
#
# Spanish:	Ella se sentó con Eva en el <unk> sofá .
# Translation:	She sat in Eva in the middle of the infernal pit .
# Target:		Aunt Rose sat with Eva on the <unk> sofa .
#
# Spanish:	Vivimos en una época de grandes desafíos e iniquidad .
# Translation:	We live in a time of great challenges and iniquity .
# Target:		We live in a time of great trouble and wickedness .
#
# Spanish:	Las cosas difíciles en nuestra vida no deberían sorprendernos .
# Translation:	The hard things in our lives should not surprise .
# Target:		The hard things in our lives should come as no surprise .
#
# Spanish:	Dijo : " No soy miembro de su iglesia .
# Translation:	He said , " I am not a member of your church .
# Target:		He said , " I ’m not a member of your church .
#
# Spanish:	Notas de dirección de la sesión del domingo por la tarde
# Translation:	Sun AM Conducting Notes
# Target:		Sun PM Conducting Notes
#
# Spanish:	¿ Cuál era la fuente de la esperanza de Pablo ?
# Translation:	What was the source of Paul ’s hope ?
# Target:		What was the source of Paul ’s hope ?
#
# Spanish:	Reconozcamos lo bueno en los demás y no sus imperfecciones .
# Translation:	Let us acknowledge the good in others and not her imperfections .
# Target:		Recognize the good in others , not their <unk> .
#
# Spanish:	Tres años después , volvió con su familia a Utah .
# Translation:	Three years later , with his family to Utah .
# Target:		He returned to Utah with his family three years later .
#
# Spanish:	“ Bandera , alto en el monte , se <unk> .
# Translation:	“ High on the hill , in the mountain , shall be entertained .
# Target:		“ High on the mountain top a banner is unfurled .
#
# Spanish:	Tomemos la resolución de ser felices independientemente de nuestras circunstancias .
# Translation:	Take the resolve to be happy regardless of our circumstances .
# Target:		Let us resolve to be happy , regardless of our circumstances .
#
# Spanish:	¡ Les ruego que no escuchen las mentiras de Satanás !
# Translation:	I pray you will not listen to Satan ’s lies !
# Target:		I plead with you not to listen to Satan ’s lies !
#
# Spanish:	En poco tiempo , nuestro cobertizo estaba repleto de conejos .
# Translation:	Soon our shed was filled with romance .
# Target:		In a very short time , our shed was bursting with <unk> .
#
# Spanish:	Testifico de ello en el nombre de Jesucristo . Amén .
# Translation:	I testify of this in the name of Jesus Christ , amen .
# Target:		Of these things I testify in the name of Jesus Christ , amen .
#
# Spanish:	No obstante , a veces creo que comprendemos mal la obediencia .
# Translation:	But sometimes I believe that we understand that we understand wrong obedience .
# Target:		But sometimes I think we misunderstand obedience .
#
# Spanish:	Como dijo el Salvador a los nefitas después de Su resurrección :
# Translation:	As the Savior said to the Nephites after His Resurrection :
# Target:		As the Savior told the Nephites following His Resurrection :
#
# Spanish:	El élder Stevenson asemeja un eclipse solar a un eclipse espiritual .
# Translation:	Elder Stevenson encourages a solar eclipse .
# Target:		Elder Stevenson <unk> a solar eclipse to a spiritual eclipse .
#
# Spanish:	En mi época no había líneas eléctricas que impedían el paso .
# Translation:	There were no lines that were electric lines .
# Target:		In our day there were no power lines to prevent access .
#
# Spanish:	Nuestro amado profeta “ los ha llamado a las filas ” .
# Translation:	Our beloved prophet “ has called them to meet . ”
# Target:		Our beloved prophet has “ called you to the colors . ”
#
# Spanish:	Su naturaleza cambiará y llegarán a ser más semejantes al Salvador ;
# Translation:	Your nature will change and become more like the Savior .
# Target:		Your very nature will be changed to become more like the Savior .
#
# Spanish:	Permítanme compartir cuatro principios que ayudarán en nuestros esfuerzos de rescate .
# Translation:	Let me share four principles that will help you in our rescue efforts .
# Target:		Let me share four principles that will help in our rescue efforts .
#
# Spanish:	Por fin salió el sol y pasamos juntos un día maravilloso .
# Translation:	For the sun , and we passed together together a wonderful day .
# Target:		Eventually the sun came out , and we had a wonderful day together .
#
# Spanish:	Hay servicio que nadie más puede prestar de la misma manera .
# Translation:	There are service that no one can serve the same way .
# Target:		There is service that no one else can give in quite the same way .
#
# Spanish:	y " cuando aún estaba lejos " , corrió hacia él .
# Translation:	And " when he was still far away , " ran to him .
# Target:		And " when he was yet a great way off , " he ran to him .
#
# Spanish:	Los que estén en contra , si los hay , pueden manifestarlo .
# Translation:	Any opposed may manifest it .
# Target:		Those opposed , if any , may manifest it .
#
# Spanish:	Al reconocer nuestra naturaleza divina , el presidente Russell M. Nelson exhortó :
# Translation:	As we recognize our divine nature , President Russell M. Nelson urged :
# Target:		Recognizing our divine nature , President Russell M. Nelson urged :
#
# Spanish:	Hermanos y hermanas , queridos amigos , Dios los conoce de forma perfecta
# Translation:	Brothers and sisters , dear friends , God knows the form of perfect way perfectly
# Target:		Brothers and sisters , dear friends , God knows you perfectly .
#
# Spanish:	Mientras hablaba , me di cuenta de que había cometido un error .
# Translation:	As I spoke , I realized that there was a mistake .
# Target:		As I spoke , I realized I had made a mistake .
#
# Spanish:	Solo entonces podremos ser <unk> de la brecha en las relaciones terrenales .
# Translation:	Only then can we be meticulously looming in mortal relationships .
# Target:		Only then can we become <unk> of the breach in earthly relationships .
#
# Spanish:	no obstante , eso no significa que debemos sentirnos perdidos ni solos .
# Translation:	But this does n’t mean we should feel lost or alone .
# Target:		But that does n’t mean we need to feel lost or alone .
#
# Spanish:	Como discípulos del Salvador , se espera que planifiquemos y nos preparemos .
# Translation:	As disciples of the Savior , we are expected to plan and prepare .
# Target:		As disciples of the Savior , we are expected to plan and prepare .
#
# Spanish:	“ Querida , necesitamos una camioneta con sistema de tracción 4x4 ” .
# Translation:	“ Dear , we need a truck truck driver in return . ”
# Target:		“ <unk> , we need a four - wheel - drive truck . ”
#
# Spanish:	Ruego la ayuda divina al aprovechar esta oportunidad de dirigirme a ustedes .
# Translation:	I pray for divine assistance by you to address you .
# Target:		I pray for heavenly help as I respond to the opportunity to address you .
#
# Spanish:	En el santo nombre de nuestro Salvador y Redentor Jesucristo . Amén .
# Translation:	In the holy name of our Savior and Redeemer , Jesus Christ , amen .
# Target:		In the holy name of our Savior and Redeemer , even Jesus Christ , amen .
#
# Spanish:	Observé cuando el secretario caminó hasta la casa del jovencito menos activo .
# Translation:	I watched as the secretary to the home of the young man ’s home .
# Target:		I was watching when the secretary walked up the street toward the less - active boy ’s house .
#
# Spanish:	La gente hace cosas buenas e importantes debido a que tiene un testimonio .
# Translation:	The people do good and important things because of a testimony has a testimony .
# Target:		People do good and important things because they have testimonies .
#
# Spanish:	Un tercer ámbito en el que podemos prestar servicio es en nuestras comunidades .
# Translation:	A third is the third in our communities .
# Target:		A third area where we can serve is in our communities .
#
# Spanish:	Para la Fortaleza de la Juventud , folleto , 2011 , pág. 43 .
# Translation:	For the Strength of Youth ( booklet , 2011 ) , 43 .
# Target:		For the Strength of Youth ( booklet , 2011 ) , 43 .
#
# Spanish:	Después regresen a Él al instante y reciban de nuevo Sus abundantes bendiciones .
# Translation:	He then reached out to Him and receive again from His very blessings .
# Target:		Then straightway return to Him and receive His abundant blessings once again .
#
# Spanish:	La última oración la ofrecerá el élder Hugo Montoya , de los Setenta .
# Translation:	The benediction will then be offered by Elder Hugo Montoya , ’s Seventy .
# Target:		The benediction will then be offered by Elder Hugo Montoya of the Seventy .
#
# Spanish:	D. y C. <unk> ; véase también D. y C. 41:1 , 12 .
# Translation:	Doctrine and Covenants 88:11 , see also Doctrine and Covenants 41:1 .
# Target:		Doctrine and Covenants <unk> ; see also Doctrine and Covenants 41:1 , 12 .
#
# Spanish:	Tienen la responsabilidad de considerar las consecuencias de cada una de sus decisiones .
# Translation:	You have the responsibility to consider the consequences of each of your decisions .
# Target:		You are responsible to think about the consequences of every choice you make .
#
# Spanish:	El asesor describió algunas de sus experiencias con el Sacerdocio Aarónico esa mañana .
# Translation:	The adviser described some of his experiences with the Aaronic Priesthood .
# Target:		This adviser described some of his experiences with the ward Aaronic Priesthood that morning .
#
# Spanish:	A veces ha estado agradecida de aferrarse a la fe de otras personas .
# Translation:	There is times of grateful to hold to the faith of others .
# Target:		At times she has been grateful to hold on to the faith of others .
#
# Spanish:	“ Israel , Jesús os llama ” , Himnos , nro . 6 .
# Translation:	“ Israel , Israel , God Is Calling , ” Hymns , no . 6 .
# Target:		“ Israel , Israel , God Is Calling , ” Hymns , no . 7 .
#
# Spanish:	Se han de compartir única y solamente con quien sea su compañero eterno .
# Translation:	They have been to share and only with whom their eternal companion .
# Target:		It is to be shared solely and only with that one who is your companion forever .
#
# Spanish:	No hay nada como trabajar juntas , tener contacto visual y conectarse emocionalmente .
# Translation:	There is nothing like together , bringing us and connecting our course .
# Target:		There ’s nothing like being arm in arm , face to face , and heart to heart with you .
#
# Spanish:	La rectitud de ustedes es el honor más grande que pueda recibir un padre .
# Translation:	Your righteousness is the greatest honor that you can receive a father .
# Target:		Your righteousness is the greatest honor any father can receive .
#
# Spanish:	No tuvieron tiempo de llegar a terrenos más elevados , a un lugar seguro .
# Translation:	They did n’t have time to come to ground , even to a safe place .
# Target:		They did not have time to get to higher ground and safety .
#
# Spanish:	Enseñanzas de los Presidentes de la Iglesia : David O. McKay , pág. <unk> .
# Translation:	Teachings of Presidents of the Church : David O. McKay ( 1888 ) , 226 .
# Target:		David O. McKay , in Conference Report , Apr. 1959 , 122 .
#
# Spanish:	Para describir su experiencia en el templo , ellos emplearon frases como las siguientes :
# Translation:	They used their experience in the temple , they used this :
# Target:		They used phrases like the following to describe their experience in the temple :
#
# Spanish:	Esta es la única Iglesia verdadera y Él es la principal piedra del ángulo .
# Translation:	This is the only true Church and He is the chief cornerstone stone .
# Target:		This is the only true Church , and He is its chief cornerstone .
#
# Spanish:	Cuando el Salvador visitó a los nefitas , hizo algo extraordinario con los niños :
# Translation:	When the Savior visited the Nephites , He made something remarkable with children :
# Target:		When the Savior visited the Nephites , He did something extraordinary with the children :
#
# Spanish:	Recibimos respuesta a nuestros interrogantes con consuelo y seguridad mediante la expiación del Salvador .
# Translation:	We experience to our questions with comfort and assurance through the Savior ’s Atonement .
# Target:		Our questions were answered with comfort and assurance through the Atonement of the Savior .
#
# Spanish:	En ese período de mi vida , pensaba que todas eran aceptables ante Dios .
# Translation:	In that period of my life , I thought that all were acceptable before God .
# Target:		At that point in my life , I thought all religions were acceptable to God .
#
# Spanish:	La Biblia es un testigo de Jesucristo ; el Libro de Mormón es otro .
# Translation:	The Bible is a witness of Jesus Christ . The Book of Mormon is another .
# Target:		The Bible is one witness of Jesus Christ ; the Book of Mormon is another .
#
# Spanish:	La restauración del Evangelio comenzó con la pregunta de un joven , José Smith .
# Translation:	The restoration of the gospel began with a young man ’s question .
# Target:		The Restoration of the gospel began with a youth , Joseph Smith , asking a question .
#
# Spanish:	Expreso mi gratitud a todos los que han compartido sus talentos en ese aspecto .
# Translation:	I express my gratitude to all who have shared their talents in that regard .
# Target:		I express my gratitude to all who have shared with us their talents in this regard .
#
# Spanish:	Esa fe puede verse fortalecida al aprender acerca de Él y vivir nuestra religión .
# Translation:	That faith can be strengthened by learning of Him and live our religion .
# Target:		Faith in the Lord Jesus Christ can be bolstered as we learn about Him and live our religion .
#
# Spanish:	La cantidad total de miembros de la Iglesia en Costa de Marfil es aproximadamente <unk> .
# Translation:	The total number of members of the Church in the Ivory Coast is Mais .
# Target:		Total Church membership in the Ivory Coast is approximately 19,000 .
#
# Spanish:	¿ O son solo aquellos siervos selectos que reúnen los requisitos mediante ordenanzas y convenios ?
# Translation:	Or are they only those who meet together through ordinances and covenants ?
# Target:		Or is it only those select servants qualified through ordinances and covenants ?
#
# Spanish:	Yo no creo que el Padre Celestial haya abandonado a Su Hijo en la cruz .
# Translation:	I do n’t believe Heavenly Father has abandoned His Son on the cross .
# Target:		I do n’t believe Father in Heaven forsook His Son on the cross .
#
# Spanish:	¿ Hay alguien en este autobús que sepa algo acerca de los mormones ? ” .
# Translation:	Is there someone on this bus ? ”
# Target:		Is there anyone on this bus who knows anything more about the Mormons ? ”
#
# Spanish:	Enseñanzas de los presidentes de la Iglesia : José Smith , 2007 , pág. 473 .
# Translation:	Teachings of Presidents of the Church : Joseph Smith ( 2007 ) , 349–57 .
# Target:		Teachings of Presidents of the Church : Joseph Smith ( 2007 ) , 444 .
#
# Spanish:	¿ Qué señal le darán al Señor para mostrarle el amor que sienten por Él ?
# Translation:	What sign will the Lord will give you a love for His love for Him ?
# Target:		What sign will you give to the Lord to show your love for Him ?
#
# Spanish:	Dios revelará la verdad a quienes la busquen tal y como consta en las Escrituras .
# Translation:	God will reveal truth to those who seek for such as prescribed in the scriptures .
# Target:		God will reveal truth to those who seek for it as prescribed in the scriptures .
#
# Spanish:	Véase 2 Corintios 3:18 ; Éter 12:27 ; Doctrina y Convenios 35:2 ; Moisés 1:39 .
# Translation:	See 2 Corinthians 3:18 ; Ether 12:27 ; Doctrine and Covenants 35:2 ; Moses 1:39 .
# Target:		See 2 Corinthians 3:18 ; Ether 12:27 ; Doctrine and Covenants 35:2 ; Moses 1:39 .
#
# Spanish:	Un padre puede haberlo sentido cuando vio a un niño caerse y <unk> la rodilla .
# Translation:	A father can have felt when he saw a little boy would be kicked and tormented .
# Target:		A father may have felt it when he saw a child fall and <unk> a knee .
#
# Spanish:	Nuestras oraciones a favor de ellos los fortalecerán al llevar el sagrado manto del apostolado .
# Translation:	Our prayers in behalf of them will strengthen the sacred robe of the apostolic mantle .
# Target:		Our prayers on their behalf will strengthen them as they bear the sacred mantle of apostleship .
#
# Spanish:	Debemos aprender a reconocer que el Salvador está siempre en el círculo cuando lo invitamos .
# Translation:	We must learn to recognize that the Savior is always in the circle when we invite it .
# Target:		We must learn to recognize that the Savior is always in the circle as we invite Him .
#
# Spanish:	Hermanos , poseemos “ el Santo Sacerdocio según el Orden del Hijo de Dios ” .
# Translation:	Brethren , we “ the Holy Ghost , after the Order of the Son of God . ”
# Target:		Brethren , we hold “ the Holy Priesthood , after the Order of the Son of God . ”
#
# Spanish:	Cuando se <unk> este edificio , pensábamos que nunca se llenaría ; pero <unk> ahora .
# Translation:	When it was depicted , we thought we would never be forced from ; but it is quite disturbing .
# Target:		When this building was planned , we thought we ’d never fill it . Just look at it now .
#
# Spanish:	Nosotros , los hermanos , no podemos reproducir la influencia sin igual que tienen ustedes ” .
# Translation:	We brethren can not duplicate your unique influence . ”
# Target:		We brethren can not duplicate your unique influence . ”
#
# Spanish:	Él dirige Su Iglesia por medio de un profeta viviente , el presidente Thomas S. Monson .
# Translation:	He leads His Church through a living prophet , President Thomas S. Monson .
# Target:		He leads His Church through a living prophet , President Thomas S. Monson .
#
# Spanish:	A través de todo ello , encontró una manera de aprender con sus hermanos del sacerdocio .
# Translation:	Through all that , he found a way to learn with his brethren from the priesthood .
# Target:		Through it all , he found a way to learn with his priesthood brethren .
#
# Spanish:	Enseñanzas de los Presidentes de la Iglesia : José Smith , 2007 , págs . 51–52 .
# Translation:	Teachings of Presidents of the Church : Joseph Smith ( 2007 ) , 49 .
# Target:		Teachings of Presidents of the Church : Joseph Smith ( 2007 ) , 49 .
#
# Spanish:	Como padres , podemos seguir adelante con la seguridad de que Dios nunca nos dejará solos .
# Translation:	As parents , we can press forward with the assurance that God will never leave us alone .
# Target:		As parents , we can proceed with the assurance God will never leave us alone .
#
# Spanish:	Nos ha confiado la autoridad de Su sacerdocio junto con las llaves para su debido uso .
# Translation:	He has entrusted the authority of His priesthood by keys to their use because of their use .
# Target:		He entrusts us with His priesthood authority complete with the keys for its proper use .
#
# Spanish:	El libro está repleto de ejemplos de mujeres que han encontrado gran gozo al guardar convenios .
# Translation:	The book is filled with examples of women who have found great joy as we keep the covenants .
# Target:		The book is filled with examples of women who have found great joy in keeping covenants .
#
# Spanish:	Cada oración ofrecida , aún por los pequeñitos , se termina en el nombre de Jesucristo .
# Translation:	Each administered in the little ones ends in the name of Jesus Christ .
# Target:		Every prayer offered , even by little children , ends in the name of Jesus Christ .
#
# Spanish:	Además , nos proporciona la motivación continua para que hagamos y guardemos nuestros convenios eternos indispensables .
# Translation:	We also provides the continual motivation for us to do and keep our indispensable eternal covenants .
# Target:		Further , it provides continual motivation for us to make and keep our indispensable eternal covenants .
#
# Spanish:	La mayor de todas las bendiciones del sacerdocio se otorga en los santos templos del Señor .
# Translation:	The greatest of all the blessings of the priesthood is given in the Lord ’s holy temples .
# Target:		The greatest of all the blessings of the priesthood are bestowed in holy temples of the Lord .
#
# Spanish:	También pueden recibir fortaleza y ánimo en su vida diaria y en sus pruebas y dificultades .
# Translation:	They can also receive strength and encouragement in their daily lives and in their trials and difficulties .
# Target:		They can also be fortified and encouraged in their daily lives and in their trials and hardships .
#
# Spanish:	Los cielos se abrieron en respuesta a la humilde súplica de un jovencito de 14 años .
# Translation:	The heavens opened to the humble plea of a young boy in 14 years .
# Target:		In response to a 14 - year - old boy ’s humble prayer , the heavens were opened .
#
# Spanish:	Sadrac , Mesac y Abed-nego fueron echados a un horno ardiente ( véase Daniel 3 ) .
# Translation:	Shadrach , Meshach , and Abed - nego a fiery furnace ( see Daniel 3 ) .
# Target:		Shadrach , Meshach , and Abed - nego were cast into a <unk> furnace ( see Daniel 3 ) .
#
# Spanish:	¿ Qué cualidades poseen y qué ejemplos dan que pueden ayudarnos en nuestro propio crecimiento espiritual ?
# Translation:	What qualities have given and what examples give to help us in our own spiritual growth ?
# Target:		What qualities do they possess and what examples do they demonstrate that can help us in our own spiritual development ?
#
# Spanish:	Aun así experimentaremos desafíos difíciles , pero seremos capaces de <unk> , superarlos y <unk> <unk> .
# Translation:	Even so we will find hard challenges , but we will be able to publish it , we will be relieved .
# Target:		We will still experience difficult challenges , but we will be able to face them , to meet them head on , and to emerge victorious .
#
# Spanish:	El adversario no está <unk> activamente nuestras reuniones de la Iglesia ; quizá sólo lo haga ocasionalmente .
# Translation:	The adversary is not basing our meetings upon the Church . It may only be only then .
# Target:		The adversary is not actively disturbing our Church meetings — perhaps only occasionally .
#
# Spanish:	“ Los niños tienen una enorme sensibilidad para las cosas espirituales ” , dice la hermana Stevens .
# Translation:	“ Children have a huge sensitivity to spiritual sensitivity . ”
# Target:		“ Children have such a sensitivity to spiritual things , ” Sister Stevens says .
#
# Spanish:	Su lealtad y su amor significa más para nosotros de los que jamás nos sea posible expresar .
# Translation:	His loyalty and love means more for us than ever to express us .
# Target:		Your loyalty and your love mean more to us than we can ever possibly say .
#
# Spanish:	Por favor , llévenlo de nuevo y léanlo ; después me gustaría que me lo <unk> ” .
# Translation:	Please take a new and read it , after I would like to myself .
# Target:		Please take it back and read it ; then I would like my book back . ”
#
# Spanish:	Antes de que comenzara la reunión , vi a un apuesto joven sentado en la primera fila .
# Translation:	Before the meeting started to start , I saw a choice behind him in the first line .
# Target:		Before the meeting began , I noticed a handsome young man sitting on the front row .
#
# Spanish:	En lugar de ello , tienen que ver los manuales , su propio corazón y el cielo .
# Translation:	Instead , they have to see the handbooks , their own hearts , and heaven .
# Target:		Instead you need to look into the handbooks , into your heart , and into heaven .
#
# Spanish:	Y mi alma tuvo hambre ; y me arrodillé ante mi Hacedor ” ( Enós 1:3–4 ) .
# Translation:	And my soul was hungry ; and I knelt down at my behalf of the eleven ” ( Enos 2:18 ) .
# Target:		And my soul hungered ; and I knelt down before my Maker ” ( Enos 1:3–4 ) .
#
# Spanish:	“ He aquí , yo soy Jesucristo , de quien los profetas testificaron que vendría al mundo .
# Translation:	“ Behold , I am Jesus Christ , whom the prophets testified shall come into the world .
# Target:		“ Behold , I am Jesus Christ , whom the prophets testified shall come into the world .
#
# Spanish:	No pueden llegar a un entendimiento de una verdad espiritual con instrumentos que no la pueden detectar .
# Translation:	You can not come to an understanding of a spiritual truth with instruments that can not steal .
# Target:		You ca n’t come to an understanding of spiritual truth with instruments that are unable to detect it .
#
# Spanish:	Considero que la respuesta se halla en un sueño que tuvo un profeta hace miles de años .
# Translation:	I consider the answer found in a dream that he had a prophet years ago .
# Target:		I believe the answer can be found in a dream that a prophet had thousands of years ago .
#
# Spanish:	<unk> un poco a la época del Antiguo Testamento para ver cómo Elí hizo esto con Samuel .
# Translation:	He yearned to be a little bit by the Old Testament to see how Eli did this to read Samuel .
# Target:		Let ’s go back in time to the Old Testament to see how Eli did just this for Samuel .
#
# Spanish:	Prepárense lo mejor que puedan y sepan que nuestro Padre Celestial magnificará sus esfuerzos humildes y obedientes .
# Translation:	Get you better than you can and know that our Heavenly Father will magnify your humble and obedient .
# Target:		Prepare as well as you can , and know that our Heavenly Father will magnify your humble and obedient efforts .
#
# Spanish:	Imagínense por un momento cómo se sentirían si fueran ustedes los receptores de palabras o actos desconsiderados .
# Translation:	Imagine for a moment how you would have felt if you were the recipients of your words or unkind actions .
# Target:		Take a moment and imagine how you would feel if you were on the receiving end of thoughtless words or actions .
#
# Spanish:	<unk> un cobertizo junto al río Misuri , en el lugar que se conocería como Winter <unk> .
# Translation:	He goes on by the shed in the river in the place he would be preceded by ending .
# Target:		They built for themselves a lean - to on the side of the Missouri River at what came to be known as Winter <unk> .
#
# Spanish:	Se le llamó para que les ayudara a hallar consuelo en la sociabilidad y el aprendizaje del Evangelio .
# Translation:	He was called to help you find comfort in the gospel greeting that you and learning from the gospel .
# Target:		His calling was to help them find comfort in sociality and gospel learning .
#
# Spanish:	Cuando el orador citaba un pasaje de las Escrituras , los miembros recitaban el versículo en voz alta .
# Translation:	When a speaker quoted a scripture , the members would say the verse aloud .
# Target:		When a speaker quoted a scripture , the members would say the verse aloud .
#
# Spanish:	Después de una carrera fantástica y que lo redimió , ganó el premio que procuró con tanta diligencia .
# Translation:	After a magnificent race and he that redeemed him , the prize he sought diligently with such diligence .
# Target:		After a <unk> , redemptive run , he won the prize he so diligently sought .
#
# Spanish:	El perseverar hasta el fin es una señal del verdadero discipulado y es esencial para la vida eterna .
# Translation:	Enduring to the end is a sign of the true discipleship and is essential to eternal life .
# Target:		Enduring to the end is a hallmark of true discipleship and is essential to eternal life .
#
# Spanish:	Sin embargo , a veces , cuando las tenemos constantemente delante de los ojos , no las apreciamos .
# Translation:	But sometimes we have consistently done in our eyes , we do not appreciate .
# Target:		However , sometimes when we have them constantly before our eyes , we take them for granted .
#
# Spanish:	Esta última opción es algo que Cindy <unk> , de Casper , Wyoming , ha usado durante años .
# Translation:	This final choice is a fairly swimmer , Wyoming , has previously announced for years .
# Target:		This latter option is something Cindy <unk> of Casper , Wyoming , has been doing for years .
#
# Spanish:	Él sanó y bendijo a las personas y les mandó que llevasen a los niños pequeños a Él .
# Translation:	He healed and blessed people and commanded them that they should be brought to Him .
# Target:		He healed and blessed the people and commanded that the little children should be brought to Him .
#
# Spanish:	Véanse , por ejemplo , 2 Nefi 9:25 ( Jacob ) y 2 Nefi 11:7 ( Nefi ) .
# Translation:	See , for example , 2 Nephi 9:25 ( Jacob ) and 2 Nephi 11:7 ( Nephi 11:7 ) .
# Target:		See , for example , 2 Nephi 9:25 ( Jacob ) and 2 Nephi 11:7 ( Nephi ) .
#
# Spanish:	Ruego que el Espíritu Santo confirme a cada uno de nosotros la veracidad de los principios que <unk> .
# Translation:	I pray that the Holy Ghost will confirm to each of us the truth of the principles that are driven by us .
# Target:		I pray the Holy Ghost will confirm to each of us the truthfulness of the principles I discuss .
#
# Spanish:	Nuestra familia tiene dos nietas en ese mundo , Sara y Emily , y un nieto , Nathan .
# Translation:	Our family has two granddaughters in that world , Sara , and Emily , and an grandson , both five - grandson and grandson .
# Target:		In that world , our family has two granddaughters , Sara and Emily , and a grandson , Nathan .
#
# Spanish:	Véase de Marshall <unk> , What Got You <unk> <unk> <unk> You There , 2007 , capítulo 3 .
# Translation:	See Errol Morris , What Teens Wish learns the repetitive Hymnal of any prejudice , 3 .
# Target:		See Marshall <unk> , What Got You Here Wo n’t Get You There ( 2007 ) , chapter 3 .
#
# Spanish:	El Libro de Mormón nos enseña sobre Jesucristo y Su evangelio de una manera sumamente milagrosa y singular .
# Translation:	The Book of Mormon teaches us about Jesus Christ and His gospel in a very real way and unique .
# Spanish:	Los oradores se han colocado en orden alfabético y los números se refieren a la primera página del discurso .
# Translation:	Speakers have been placed in order and the numbers referred to the first page of the talk .
# Target:		The speakers are listed in alphabetical order , and the number refers to the first page of the talk .
#
# Spanish:	Él puede quitar el dolor y pesar que sienten y hacerlos limpios nuevamente mediante el poder de Su expiación .
# Translation:	He can take the pain and sorrow that feel and clean again through the power of His Atonement .
# Target:		He can remove the pain and sorrow you feel and make you clean again through the power of His Atonement .
#
# Spanish:	Hermanos y hermanas , el hacer con diligencia las cosas que más importan nos llevará al Salvador del mundo .
# Translation:	Brothers and sisters , do , do we with diligence that the Savior ’s things will matter to us .
# Target:		Brothers and sisters , diligently doing the things that matter most will lead us to the Savior of the world .
#
# Spanish:	Ambas invitaciones , si se aceptan , requerirán un esfuerzo disciplinado durante un largo tiempo para lograr las recompensas .
# Translation:	Both invitations , if we accept , will require a disciplined effort during an extended period of time to achieve the rewards .
# Target:		Both invitations , if accepted , will require a disciplined effort over an extended period of time to reap the rewards .
#
# Spanish:	Seguramente no estaba de paseo a solas , pues debe haber sabido que había ladrones esperando a los <unk> .
# Translation:	Surely it was not in alone , knowing that there should be known who would be expecting to arrange the ditch .
# Target:		It is not likely that he was taking a stroll alone since he must have known that <unk> waited for the <unk> .
#
# Spanish:	Empezó a subir por sí mismo , mano sobre mano , sabiendo que si no se <unk> ciertamente <unk> .
# Translation:	He began to come down to the same hand , knowing that if it were not overshadowed by a swift blast to the rooftop .
# Target:		He began pulling himself up , hand over hand , knowing that if he lost his grip , he would almost certainly perish .
#
# Spanish:	Al escuchar los mensajes de esta conferencia se conmoverán nuestros corazones y haremos resoluciones y compromisos de ser mejores .
# Translation:	As we listen to the messages of this conference will be touched by our hearts and commitments to become better .
# Target:		As we listen to the messages of this conference , we will be touched in our hearts and make resolutions and commitments to do better .
#
# Spanish:	El carácter se <unk> pacientemente con los hilos de los principios , la doctrina y la obediencia puestos en práctica .
# Translation:	The character is streamed over the most significant principles of the doctrine , doctrine , and obedience .
# Target:		Character is woven patiently from threads of applied principle , doctrine , and obedience .
#
# Spanish:	Muchos se han convertido a la Iglesia a través de amigos con quienes han participado en actividades de la Iglesia .
# Translation:	Many have become the Church through friends who participated in and who participated in activities .
# Target:		Many nonmembers have come into the Church through friends who have involved them in Church activities .
#
# Spanish:	Pero la verdad del Señor no cambia según las modas , la popularidad ni las encuestas de la opinión pública .
# Translation:	But the Lord ’s truth does n’t change even the apparent , or we attempt of public mind .
# Target:		But the Lord ’s truth is not altered by fads , popularity , or public opinion polls .
#
# Spanish:	Debemos recordar que la condición para que se nos perdonen nuestros pecados y ofensas es que perdonemos a los demás .
# Translation:	We need to remember that condition as our sins and let ourselves be determined to forgive others .
# Target:		We must remember that forgiveness of our own sins and offenses is conditioned upon our forgiving others .
#
# Spanish:	Ella era extremadamente inteligente y sentía frustración cuando trataba de entender y <unk> sentido a las cosas a su alrededor .
# Translation:	She was extremely anxious and feeling frustration when she was trying to understand and hung up the things about her .
